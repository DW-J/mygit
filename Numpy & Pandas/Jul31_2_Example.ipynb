# %%
import numpy as np

# data 폴더 안에 있는 births.txt파일을 load하기
birth = np.loadtxt('data/births.txt', delimiter=',', dtype=np.int64)

# %%
print(birth.shape)
print(type(birth))
# Out:
# (132, 3)
# <class 'numpy.ndarray'>

# %%
birth

# 결과 : 연도, 남자아이 수, 여자아이 수 로 구성
# Out:
# array([[   1880,   90993,  110491],
#        [   1881,   91954,  100745],
#        [   1882,  107850,  113688],
#        [   1883,  112321,  104629],
#        [   1884,  129022,  114445],
#        [   1885,  133055,  107800],
#        [   1886,  144535,  110784],
#        [   1887,  145982,  101414],
#        [   1888,  178627,  120853],
#        [   1889,  178366,  110584],
#        [   1890,  190377,  111025],
#        [   1891,  185482,  101196],
#        [   1892,  212346,  122037],
#        [   1893,  212906,  112317],
#        [   1894,  222922,  115772],
#        [   1895,  233630,  117398],
#        [   1896,  237920,  119570],
#        [   1897,  234202,  112758],
#        [   1898,  258770,  122693],
#        [   1899,  233023,  106212],
#        [   1900,  299828,  150499],
#        [   1901,  239348,  106471],
#        [   1902,  264077,  122659],
#        [   1903,  261973,  119234],
#        [   1904,  275371,  128125],
#        [   1905,  291629,  132319],
#        [   1906,  295303,  133159],
#        [   1907,  318566,  146833],
#        [   1908,  334313,  154344],
#        [   1909,  347228,  163999],
#        [   1910,  396501,  194218],
#        [   1911,  418299,  225968],
#        [   1912,  558103,  429945],
#        [   1913,  624518,  512557],
#        [   1914,  761548,  654762],
#        [   1915,  983874,  848603],
#        [   1916, 1044323,  890099],
#        [   1917, 1081280,  925511],
#        [   1918, 1157647, 1013537],
#        [   1919, 1130145,  980149],
#        [   1920, 1198283, 1064463],
#        [   1921, 1232999, 1101457],
#        [   1922, 1200919, 1088287],
#        [   1923, 1206330, 1096168],
#        [   1924, 1248876, 1132751],
#        [   1925, 1217352, 1115958],
#        [   1926, 1185304, 1110505],
#        [   1927, 1192330, 1126717],
#        [   1928, 1153117, 1107518],
#        [   1929, 1116422, 1075313],
#        [   1930, 1125761, 1097176],
#        [   1931, 1064497, 1039127],
#        [   1932, 1066994, 1043808],
#        [   1933, 1007710,  991127],
#        [   1934, 1044039, 1032291],
#        [   1935, 1048428, 1040930],
#        [   1936, 1040202, 1036974],
#        [   1937, 1063872, 1066309],
#        [   1938, 1103277, 1108841],
#        [   1939, 1096518, 1106544],
#        [   1940, 1143325, 1158900],
#        [   1941, 1207919, 1227941],
#        [   1942, 1350545, 1380774],
#        [   1943, 1395082, 1426846],
#        [   1944, 1327104, 1362555],
#        [   1945, 1307028, 1345610],
#        [   1946, 1571184, 1623650],
#        [   1947, 1772644, 1829223],
#        [   1948, 1697814, 1754469],
#        [   1949, 1710825, 1773725],
#        [   1950, 1713180, 1790673],
#        [   1951, 1800042, 1881080],
#        [   1952, 1854698, 1944277],
#        [   1953, 1880326, 1969777],
#        [   1954, 1941682, 2037374],
#        [   1955, 1954664, 2057918],
#        [   1956, 2007512, 2113694],
#        [   1957, 2044160, 2155866],
#        [   1958, 2010884, 2120712],
#        [   1959, 2023044, 2133509],
#        [   1960, 2022093, 2132717],
#        [   1961, 2017316, 2122502],
#        [   1962, 1966548, 2068945],
#        [   1963, 1927217, 2031755],
#        [   1964, 1894594, 1993270],
#        [   1965, 1765001, 1861378],
#        [   1966, 1691868, 1783964],
#        [   1967, 1650764, 1744527],
#        [   1968, 1640103, 1738928],
#        [   1969, 1686947, 1789732],
#        [   1970, 1748147, 1859594],
#        [   1971, 1663475, 1769201],
#        [   1972, 1521185, 1622666],
#        [   1973, 1458139, 1559338],
#        [   1974, 1467413, 1573105],
#        [   1975, 1457699, 1562207],
#        [   1976, 1465096, 1569904],
#        [   1977, 1532997, 1643684],
#        [   1978, 1531658, 1642250],
#        [   1979, 1605051, 1721947],
#        [   1980, 1659933, 1783876],
#        [   1981, 1667465, 1790907],
#        [   1982, 1692678, 1813970],
#        [   1983, 1670061, 1791732],
#        [   1984, 1682973, 1803830],
#        [   1985, 1720036, 1847032],
#        [   1986, 1714664, 1840164],
#        [   1987, 1737891, 1865662],
#        [   1988, 1779839, 1912602],
#        [   1989, 1843105, 1999999],
#        [   1990, 1897709, 2052543],
#        [   1991, 1874434, 2019463],
#        [   1992, 1843304, 1996388],
#        [   1993, 1808379, 1960397],
#        [   1994, 1785074, 1931157],
#        [   1995, 1757927, 1902832],
#        [   1996, 1752249, 1893378],
#        [   1997, 1739806, 1884122],
#        [   1998, 1765915, 1910250],
#        [   1999, 1772632, 1918809],
#        [   2000, 1814601, 1962406],
#        [   2001, 1799049, 1941251],
#        [   2002, 1795206, 1939815],
#        [   2003, 1825359, 1973434],
#        [   2004, 1834145, 1982794],
#        [   2005, 1845379, 1994841],
#        [   2006, 1898463, 2052377],
#        [   2007, 1919408, 2072139],
#        [   2008, 1887234, 2036289],
#        [   2009, 1832925, 1979303],
#        [   2010, 1772738, 1913851],
#        [   2011, 1753500, 1893230]])

# %%
import matplotlib.pyplot as plt

# %%
a = np.array([1, 2, 3, 4, 5])
b = np.array([11, 12, 13, 14, 15])

plt.plot(a, b, 'bo--')
plt.bar(a, b)

plt.title('Kor')
plt.xlabel('Student_num')
plt.ylabel('Score')
plt.show()

# %%
# 1. 남자아이, 여자아이 출생 수 평균을 구해주세요 (정수로 출력)
# maleAvg = int(np.average(birth[:,1]))
# femaleAvg = int(np.average(birth[:,2]))
# print(maleAvg)
# print(femaleAvg)
print("남자아이 평균 : ", int(birth[:, 1].mean()))
print("남자아이 평균 : ", int(birth[:, 2].mean()))
# Out:
# 남자아이 평균 :  1225776
# 남자아이 평균 :  1245399

# %%
# 2. 2000년 부터의 데이터를 구해주세요 (2000 ~ 2011)
#   연도  남자      여자
#   2000  1234567   1234567
#   ...
# 2000년 부터의 데이터를 구하라
# print("            연도", "  남자", "    여자")
# birth[birth[:,0] >= 2000]
print("연도", "남자", "여자", sep="\t")
print("=" * 30)
for y, m, f in birth[birth[:,0] >= 2000]
  print(y, m, f, sep="\t")
# Out:
#             연도   남자     여자
# array([[   2000, 1814601, 1962406],
#        [   2001, 1799049, 1941251],
#        [   2002, 1795206, 1939815],
#        [   2003, 1825359, 1973434],
#        [   2004, 1834145, 1982794],
#        [   2005, 1845379, 1994841],
#        [   2006, 1898463, 2052377],
#        [   2007, 1919408, 2072139],
#        [   2008, 1887234, 2036289],
#        [   2009, 1832925, 1979303],
#        [   2010, 1772738, 1913851],
#        [   2011, 1753500, 1893230]])

# %%
# 3. 남자아이 출생이 가장 많은 연도와 남자아이 출생수를 구해주세요
# maleMax = birth[np.argmax(birth[:,1])]
# print(maleMax[0], maleMax[1])
#  argmax() : 가장 많은 값의 index를 반환
birth[birth[:,1].argmax()]
y = birth[birth[birth[:,1].argmax()]][0]  # 연도
b = birth[birth[birth[:,1].argmax()]][1]  # 남자아이 출생 수

print("연도", "남자아이", sep="\t")
print(y, b, sep="\t")
# Out:
# 1957 2044160

# %%
# 4. 여자아이 출생이 가장 많았던 top5를 수해주세요 (연도, 여자아이 수)
top5_girls = np.sort(birth[:, 2])[-1: -6: -1] # 역순으로 찾을때는 인덱스에 -1
print(top5_girls)

print("연도", "여자아이수", sep="\t")
print("=" * 20)
for i in birth:
  for j in top5_girls:
    if(i[2] == j):
      print(i[0], j, sep="\t")
# Out:
# [2155866 2133509 2132717 2122502 2120712]
# 연도	여자아이수
# ====================
# 1957	2155866
# 1958	2120712
# 1959	2133509
# 1960	2132717
# 1961	2122502

# %%
# 5. 여자아이의 출생률(%)을 구하고, 각 연도별로 여자아이 출생수가 차지하는 비율을
#     데이터로 보여주세요. (소수점 둘째자리까지)
#     연도    남자      여자      여자출생률
#     1880    123123    100000    41.xx
#     ...

girls_ratio = ((birth[:, 2] / (birth[:, 1] + birth[:, 2])) * 100).round(2)
girls_ratio

print("연도", "남아", "여아", "여아 출생률", sep="\t")
print("=" * 40)
for y, b, g, gr in zip(birth[:, 0], birth[:, 1], birth[:, 2], girls_ratio):
  print(y, b, g, gr, sep="\t")
# Out:
# 연도	남아	여아	여아 출생률
# ========================================
# 1880	90993	110491	54.84
# 1881	91954	100745	52.28
# 1882	107850	113688	51.32
# 1883	112321	104629	48.23
# 1884	129022	114445	47.01
# 1885	133055	107800	44.76
# 1886	144535	110784	43.39
# 1887	145982	101414	40.99
# 1888	178627	120853	40.35
# 1889	178366	110584	38.27
# 1890	190377	111025	36.84
# 1891	185482	101196	35.3
# 1892	212346	122037	36.5
# 1893	212906	112317	34.54
# 1894	222922	115772	34.18
# 1895	233630	117398	33.44
# 1896	237920	119570	33.45
# 1897	234202	112758	32.5
# 1898	258770	122693	32.16
# 1899	233023	106212	31.31
# 1900	299828	150499	33.42
# 1901	239348	106471	30.79
# 1902	264077	122659	31.72
# 1903	261973	119234	31.28
# 1904	275371	128125	31.75
# 1905	291629	132319	31.21
# 1906	295303	133159	31.08
# 1907	318566	146833	31.55
# 1908	334313	154344	31.59
# 1909	347228	163999	32.08
# 1910	396501	194218	32.88
# 1911	418299	225968	35.07
# 1912	558103	429945	43.51
# 1913	624518	512557	45.08
# 1914	761548	654762	46.23
# 1915	983874	848603	46.31
# 1916	1044323	890099	46.01
# 1917	1081280	925511	46.12
# 1918	1157647	1013537	46.68
# 1919	1130145	980149	46.45
# 1920	1198283	1064463	47.04
# 1921	1232999	1101457	47.18
# 1922	1200919	1088287	47.54
# 1923	1206330	1096168	47.61
# 1924	1248876	1132751	47.56
# 1925	1217352	1115958	47.83
# 1926	1185304	1110505	48.37
# 1927	1192330	1126717	48.59
# 1928	1153117	1107518	48.99
# 1929	1116422	1075313	49.06
# 1930	1125761	1097176	49.36
# 1931	1064497	1039127	49.4
# 1932	1066994	1043808	49.45
# 1933	1007710	991127	49.59
# 1934	1044039	1032291	49.72
# 1935	1048428	1040930	49.82
# 1936	1040202	1036974	49.92
# 1937	1063872	1066309	50.06
# 1938	1103277	1108841	50.13
# 1939	1096518	1106544	50.23
# 1940	1143325	1158900	50.34
# 1941	1207919	1227941	50.41
# 1942	1350545	1380774	50.55
# 1943	1395082	1426846	50.56
# 1944	1327104	1362555	50.66
# 1945	1307028	1345610	50.73
# 1946	1571184	1623650	50.82
# 1947	1772644	1829223	50.79
# 1948	1697814	1754469	50.82
# 1949	1710825	1773725	50.9
# 1950	1713180	1790673	51.11
# 1951	1800042	1881080	51.1
# 1952	1854698	1944277	51.18
# 1953	1880326	1969777	51.16
# 1954	1941682	2037374	51.2
# 1955	1954664	2057918	51.29
# 1956	2007512	2113694	51.29
# 1957	2044160	2155866	51.33
# 1958	2010884	2120712	51.33
# 1959	2023044	2133509	51.33
# 1960	2022093	2132717	51.33
# 1961	2017316	2122502	51.27
# 1962	1966548	2068945	51.27
# 1963	1927217	2031755	51.32
# 1964	1894594	1993270	51.27
# 1965	1765001	1861378	51.33
# 1966	1691868	1783964	51.32
# 1967	1650764	1744527	51.38
# 1968	1640103	1738928	51.46
# 1969	1686947	1789732	51.48
# 1970	1748147	1859594	51.54
# 1971	1663475	1769201	51.54
# 1972	1521185	1622666	51.61
# 1973	1458139	1559338	51.68
# 1974	1467413	1573105	51.74
# 1975	1457699	1562207	51.73
# 1976	1465096	1569904	51.73
# 1977	1532997	1643684	51.74
# 1978	1531658	1642250	51.74
# 1979	1605051	1721947	51.76
# 1980	1659933	1783876	51.8
# 1981	1667465	1790907	51.78
# 1982	1692678	1813970	51.73
# 1983	1670061	1791732	51.76
# 1984	1682973	1803830	51.73
# 1985	1720036	1847032	51.78
# 1986	1714664	1840164	51.77
# 1987	1737891	1865662	51.77
# 1988	1779839	1912602	51.8
# 1989	1843105	1999999	52.04
# 1990	1897709	2052543	51.96
# 1991	1874434	2019463	51.86
# 1992	1843304	1996388	51.99
# 1993	1808379	1960397	52.02
# 1994	1785074	1931157	51.97
# 1995	1757927	1902832	51.98
# 1996	1752249	1893378	51.94
# 1997	1739806	1884122	51.99
# 1998	1765915	1910250	51.96
# 1999	1772632	1918809	51.98
# 2000	1814601	1962406	51.96
# 2001	1799049	1941251	51.9
# 2002	1795206	1939815	51.94
# 2003	1825359	1973434	51.95
# 2004	1834145	1982794	51.95
# 2005	1845379	1994841	51.95
# 2006	1898463	2052377	51.95
# 2007	1919408	2072139	51.91
# 2008	1887234	2036289	51.9
# 2009	1832925	1979303	51.92
# 2010	1772738	1913851	51.91
# 2011	1753500	1893230	51.92

# %%
# 6. 2000년 이후 데이터에 대해 출생량을 구하고,
#   남자아이 수가 1800000 이상이면 '많음', 아니면 '적음' 이라는 내용을 출력
after_2000 = birth[birth[:,0] >= 2000]
# print(after_2000)

boys = after_2000[:, 1]
# print(boys)

amount = np.where(boys >= 1800000, '많음', '적음')
# print(amount)

for y, b, amt in zip(after_2000[:, 0], boys, amount):
  print(y, b, amt)
# Out:
# 2000 1814601 많음
# 2001 1799049 적음
# 2002 1795206 적음
# 2003 1825359 많음
# 2004 1834145 많음
# 2005 1845379 많음
# 2006 1898463 많음
# 2007 1919408 많음
# 2008 1887234 많음
# 2009 1832925 많음
# 2010 1772738 적음
# 2011 1753500 적음

# %%
# 7. 1800년대, 1900년대, 2000년대의 각 남자아이, 여자아이 출생수의 평균을 구해주세요
print("1800년대")
print("남아 평균", "여아 평균")
k_1800s = birth[ (birth[:, 0] >= 1800) & (birth[:, 0] < 1900) ][:, 1:]
# print(k_1800s)
print(k_1800s.mean(axis=  0)[0], k_1800s.mean(axis=  0)[1])

print()

print("1900년대")
print("남아 평균", "여아 평균")
k_1900s = birth[ (birth[:, 0] >= 1900) & (birth[:, 0] < 2000) ][:, 1:]
print(k_1900s.mean(axis =  0)[0], k_1900s.mean(axis =  0)[1])

print()

print("2000년대")
print("남아 평균", "여아 평균")
k_2000s = birth[ (birth[:, 0] >= 2000) ][:, 1:]
print(k_2000s.mean(axis =  0)[0].round(2), k_2000s.mean(axis =  0)[1])
# Out:
# 1800년대
# 남아 평균 여아 평균
# 176714.15 111820.55
#
# 1900년대
# 남아 평균 여아 평균
# 1362901.51 1384145.55
#
# 2000년대
# 남아 평균 여아 평균
# 1831500.58 1978477.5

# %%
# 8. 여자아이 출생수 25% ~ 75% 사이의 값을 구해주세요 (연도, 여자아이 출생 수)

g_q25 = np.quantile(birth[:, 2], 0.25)
g_q75 = np.quantile(birth[:, 2], 0.75)
# print(g_q25, g_q75)
print(birth[ (birth[:, 2] >= g_q25) & (birth[:, 2] >= g_q75)] [:, [0, 2]])
# Out:
# [[   1952 1944277]
#  [   1953 1969777]
#  [   1954 2037374]
#  [   1955 2057918]
#  [   1956 2113694]
#  [   1957 2155866]
#  [   1958 2120712]
#  [   1959 2133509]
#  [   1960 2132717]
#  [   1961 2122502]
#  [   1962 2068945]
#  [   1963 2031755]
#  [   1964 1993270]
#  [   1988 1912602]
#  [   1989 1999999]
#  [   1990 2052543]
#  [   1991 2019463]
#  [   1992 1996388]
#  [   1993 1960397]
#  [   1994 1931157]
#  [   1998 1910250]
#  [   1999 1918809]
#  [   2000 1962406]
#  [   2001 1941251]
#  [   2002 1939815]
#  [   2003 1973434]
#  [   2004 1982794]
#  [   2005 1994841]
#  [   2006 2052377]
#  [   2007 2072139]
#  [   2008 2036289]
#  [   2009 1979303]
#  [   2010 1913851]]

# %%
# 9. 2000년대 남자아이 데이터를 bar 차트로 나타내주세요
b_2000s = birth[birth[:, 0] >= 2000][:, 0:2]
print(b_2000s)

plt.bar(b_2000s[:, 0], b_2000s[:, 1], color="salmon")
plt.title("2000s boys birth")
plt.xlabel("year")
plt.ylabel("birth")
plt.show()
# Out:
# [[   2000 1814601]
#  [   2001 1799049]
#  [   2002 1795206]
#  [   2003 1825359]
#  [   2004 1834145]
#  [   2005 1845379]
#  [   2006 1898463]
#  [   2007 1919408]
#  [   2008 1887234]
#  [   2009 1832925]
#  [   2010 1772738]
#  [   2011 1753500]]
